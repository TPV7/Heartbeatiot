# %% [markdown]
# <a href="https://colab.research.google.com/github/TPV7/Heartbeatiot/blob/main/Training_Assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df=pd.read_csv('/content/drive/MyDrive/DATA_SET.csv')
df.head(20)
# Out:
#    Training area                  Project area  # of members Interested
# 0           IBM           Clould Strategy Team                       41
# 1           IBM                        AI Team                       29
# 2           IBM          Image processing team                       12
# 3            SAP                      ERP Team                       16
# 4            SAP  Supply Chain Management Team                       32
# 5            AWS           Cloud Strategy Team                       22
# 6            AWS     Cloud Implementation Team                       45
# 7            AWS                      ERP Team                       34
# 8           IoT            Cloud security Team                       24
# 9            IoT                      ERP Team                       31
# 10     Security            Cloud security Team                        8
# 11      Security           Cloud Strategy Team                       27
# 12           SDN           Cloud security Team                       12
# 13           SDN           Cloud Strategy Team                       22
# 14           SDN     Cloud Implementation Team                       30
# 15  Cryptography           Cloud security Team                       17
# 16  Cryptography                      ERP team                       24
# 17         Scrum           Cloud Strategy Team                       11
# 18         Scrum  Supply Chain Management Team                       29
# 19         Scrum                      ERP Team                       34

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
df=pd.read_csv('/content/drive/MyDrive/DATA_SET.csv')
print(df)
# Out:
#         Training area                  Project area  # of members Interested
# 0                IBM           Clould Strategy Team                       41
# 1                IBM                        AI Team                       29
# 2                IBM          Image processing team                       12
# 3                 SAP                      ERP Team                       16
# 4                 SAP  Supply Chain Management Team                       32
# 5                 AWS           Cloud Strategy Team                       22
# 6                 AWS     Cloud Implementation Team                       45
# 7                 AWS                      ERP Team                       34
# 8                IoT            Cloud security Team                       24
# 9                 IoT                      ERP Team                       31
# 10          Security            Cloud security Team                        8
# 11           Security           Cloud Strategy Team                       27
# 12                SDN           Cloud security Team                       12
# 13                SDN           Cloud Strategy Team                       22
# 14                SDN     Cloud Implementation Team                       30
# 15       Cryptography           Cloud security Team                       17
# 16       Cryptography                      ERP team                       24
# 17              Scrum           Cloud Strategy Team                       11
# 18              Scrum  Supply Chain Management Team                       29
# 19              Scrum                      ERP Team                       34
# 20              Scrum     Cloud Implementation Team                       10
# 21  quantum computing           Cloud security Team                       42
# 22  quantum computing                       AI Team                       19

# %%
df.index = df['Training area']
df =  df.sort_values(by= '# of members Interested',ascending=False)
print(df)
# Out:
#                        Training area                  Project area  \
# Training area
# AWS                              AWS     Cloud Implementation Team
# quantum computing  quantum computing           Cloud security Team
# IBM                             IBM           Clould Strategy Team
# Scrum                          Scrum                      ERP Team
# AWS                              AWS                      ERP Team
# SAP                              SAP  Supply Chain Management Team
# IoT                              IoT                      ERP Team
# SDN                              SDN     Cloud Implementation Team
# IBM                             IBM                        AI Team
# Scrum                          Scrum  Supply Chain Management Team
# Security                    Security           Cloud Strategy Team
# IoT                             IoT            Cloud security Team
# Cryptography            Cryptography                      ERP team
# SDN                              SDN           Cloud Strategy Team
# AWS                              AWS           Cloud Strategy Team
# quantum computing  quantum computing                       AI Team
# Cryptography            Cryptography           Cloud security Team
# SAP                              SAP                      ERP Team
# SDN                              SDN           Cloud security Team
# IBM                             IBM          Image processing team
# Scrum                          Scrum           Cloud Strategy Team
# Scrum                          Scrum     Cloud Implementation Team
# Security                   Security            Cloud security Team
#
#                    # of members Interested  cumulativePercentage
# Training area
# AWS                                     45                  7.88
# quantum computing                       42                 15.24
# IBM                                     41                 22.42
# Scrum                                   34                 28.37
# AWS                                     34                 34.33
# SAP                                     32                 39.93
# IoT                                     31                 45.36
# SDN                                     30                 50.61
# IBM                                     29                 55.69
# Scrum                                   29                 60.77
# Security                                27                 65.50
# IoT                                     24                 69.70
# Cryptography                            24                 73.91
# SDN                                     22                 77.76
# AWS                                     22                 81.61
# quantum computing                       19                 84.94
# Cryptography                            17                 87.92
# SAP                                     16                 90.72
# SDN                                     12                 92.82
# IBM                                     12                 94.92
# Scrum                                   11                 96.85
# Scrum                                   10                 98.60
# Security                                 8                100.00

# %%
df["cumulativePercentage"]=df["# of members Interested"].cumsum()/df["# of members Interested"].sum()*100
df["cumulativePercentage"]=df["cumulativePercentage"].apply(lambda x: round(x,2))
print(df)
# Out:
#                        Training area                  Project area  \
# Training area
# AWS                              AWS     Cloud Implementation Team
# quantum computing  quantum computing           Cloud security Team
# IBM                             IBM           Clould Strategy Team
# Scrum                          Scrum                      ERP Team
# AWS                              AWS                      ERP Team
# SAP                              SAP  Supply Chain Management Team
# IoT                              IoT                      ERP Team
# SDN                              SDN     Cloud Implementation Team
# IBM                             IBM                        AI Team
# Scrum                          Scrum  Supply Chain Management Team
# Security                    Security           Cloud Strategy Team
# IoT                             IoT            Cloud security Team
# Cryptography            Cryptography                      ERP team
# SDN                              SDN           Cloud Strategy Team
# AWS                              AWS           Cloud Strategy Team
# quantum computing  quantum computing                       AI Team
# Cryptography            Cryptography           Cloud security Team
# SAP                              SAP                      ERP Team
# SDN                              SDN           Cloud security Team
# IBM                             IBM          Image processing team
# Scrum                          Scrum           Cloud Strategy Team
# Scrum                          Scrum     Cloud Implementation Team
# Security                   Security            Cloud security Team
#
#                    # of members Interested  cumulativePercentage
# Training area
# AWS                                     45                  7.88
# quantum computing                       42                 15.24
# IBM                                     41                 22.42
# Scrum                                   34                 28.37
# AWS                                     34                 34.33
# SAP                                     32                 39.93
# IoT                                     31                 45.36
# SDN                                     30                 50.61
# IBM                                     29                 55.69
# Scrum                                   29                 60.77
# Security                                27                 65.50
# IoT                                     24                 69.70
# Cryptography                            24                 73.91
# SDN                                     22                 77.76
# AWS                                     22                 81.61
# quantum computing                       19                 84.94
# Cryptography                            17                 87.92
# SAP                                     16                 90.72
# SDN                                     12                 92.82
# IBM                                     12                 94.92
# Scrum                                   11                 96.85
# Scrum                                   10                 98.60
# Security                                 8                100.00

# %%
fig, ax = plt.subplots()
ax.bar(df.index, df["# of members Interested"], color="C0")
ax.set_xticklabels(df['Training area'], rotation=45)
ax2 = ax.twinx()
ax2.plot(df.index, df["cumulativePercentage"], color="C1", marker="D", ms=7
         , label=df['cumulativePercentage'])
ax2.yaxis.set_major_formatter(PercentFormatter())
ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C1")

for index, v in df.iterrows():
  label = round(v['cumulativePercentage'],1)
  plt.annotate(label, xy=(v['Training area'],v['cumulativePercentage']))
